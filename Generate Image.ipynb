# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from keras.preprocessing import image
from keras.models import Sequential, Model
from keras.layers import Dense, LeakyReLU, BatchNormalization, Reshape, Flatten, Input
from keras.models import load_model
from keras.optimizers import Adam
import math
# Out:
# 2023-12-14 09:40:19.376857: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-14 09:40:19.504590: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 09:40:19.504632: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 09:40:19.505111: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 09:40:19.568185: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-14 09:40:19.569600: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-14 09:40:20.520227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load Generator
generator = load_model("generator_model.h5")
# Out:
# 2023-12-14 09:40:22.816266: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 201326592 exceeds 10% of free system memory.
# 2023-12-14 09:40:22.919186: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 201326592 exceeds 10% of free system memory.
# 2023-12-14 09:40:23.098305: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 201326592 exceeds 10% of free system memory.
# 2023-12-14 09:40:24.141477: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 201326592 exceeds 10% of free system memory.
# 2023-12-14 09:40:24.310004: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 201326592 exceeds 10% of free system memory.

# %%
noise = np.random.normal(0, 1, size=[1, 100])
generated_images = generator.predict(noise)
generated_images = generated_images.reshape(1, 128, 128, 3)
plt.figure(figsize=(12,6))
for img in generated_images:
  plt.imshow((img * 255).astype(np.uint8), cmap='viridis', interpolation="nearest")
  plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
